# %% [markdown]
# INITIALIZATION

# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from collections import defaultdict
from scipy.stats import pearsonr


data_folder = './DATA/'
raw_data_folder = data_folder+'dataset/'
artists_raw_data = raw_data_folder+'artists.csv'
tracks_raw_data = raw_data_folder+'tracks.csv'

# %% [markdown]
# DATA VISUALIZATION

# %%
artists = pd.read_csv(artists_raw_data, sep=';', index_col=0)
tracks = pd.read_csv(tracks_raw_data, sep=',', index_col=0)

# print(artists)

print(tracks)
# Out:
#             id_artist    name_artist  \
# id
# TR934808  ART04205421  Rosa Chemical
# TR760029  ART04205421  Rosa Chemical
# TR916821  ART04205421  Rosa Chemical
# TR480968  ART04205421  Rosa Chemical
# TR585039  ART04205421  Rosa Chemical
# ...               ...            ...
# TR434449  ART02733420      Marracash
# TR826351  ART02733420      Marracash
# TR529809  ART02733420      Marracash
# TR280904  ART02733420      Marracash
# TR552777  ART02733420      Marracash
#
#                                                  full_title  \
# id
# TR934808    ​polka 2 :-/ by Rosa Chemical (Ft. Ernia & Guè)
# TR760029         POLKA by Rosa Chemical (Ft. Thelonious B.)
# TR916821  ​britney ;-) by Rosa Chemical (Ft. MamboLosco ...
# TR480968                  CEO by Rosa Chemical (Ft. Taxi B)
# TR585039                LONDRA by Rosa Chemical (Ft. Rkomi)
# ...                                                     ...
# TR434449  Badabum Cha Cha - Gabri Ponte & Paki Rmx (Radi...
# TR826351  Senza Un Posto Nel Mondo - Alternative Version...
# TR529809  Badabum Cha Cha - Gabri Ponte & Paki Rmx (Exte...
# TR280904                                 Tempo by Marracash
# TR552777                            Giufa Cafe by Marracash
#
#                                                       title  \
# id
# TR934808                                       ​polka 2 :-/
# TR760029                                              POLKA
# TR916821                                       ​britney ;-)
# TR480968                                                CEO
# TR585039                                             LONDRA
# ...                                                     ...
# TR434449  Badabum Cha Cha - Gabri Ponte & Paki Rmx (Radi...
# TR826351     Senza Un Posto Nel Mondo - Alternative Version
# TR529809  Badabum Cha Cha - Gabri Ponte & Paki Rmx (Exte...
# TR280904                                              Tempo
# TR552777                                         Giufa Cafe
#
#              featured_artists primary_artist language  \
# id
# TR934808           Ernia, Guè  Rosa Chemical       pl
# TR760029        Thelonious B.  Rosa Chemical       en
# TR916821  MamboLosco, RADICAL  Rosa Chemical       en
# TR480968               Taxi B  Rosa Chemical       it
# TR585039                Rkomi  Rosa Chemical       en
# ...                       ...            ...      ...
# TR434449                  NaN      Marracash       it
# TR826351        Tiziano Ferro      Marracash       it
# TR529809                  NaN      Marracash       it
# TR280904                  NaN      Marracash       it
# TR552777                  NaN      Marracash       it
#
#                                       album  stats_pageviews  swear_IT  ...  \
# id                                                                      ...
# TR934808                   FOREVER AND EVER         196033.0        13  ...
# TR760029                   FOREVER AND EVER         164450.0         9  ...
# TR916821                   FOREVER AND EVER          58313.0        16  ...
# TR480968                  OKAY OKAY !! - EP          39890.0         8  ...
# TR585039                   FOREVER AND EVER          35432.0         1  ...
# ...                                     ...              ...       ...  ...
# TR434449      Badabum Cha Cha (The Remixes)              NaN         0  ...
# TR826351  Senza Un Posto Nel Mondo – Single              NaN         1  ...
# TR529809      Badabum Cha Cha (The Remixes)              NaN         0  ...
# TR280904                                NaN              NaN         0  ...
# TR552777                                NaN              NaN         0  ...
#
#           album_type disc_number track_number duration_ms  explicit  \
# id
# TR934808       album         1.0          3.0    207761.0      True
# TR760029       album         1.0          3.0    207761.0      True
# TR916821       album         1.0          1.0    193544.0      True
# TR480968      single         1.0          2.0    169000.0      True
# TR585039       album         1.0          8.0    194779.0      True
# ...              ...         ...          ...         ...       ...
# TR434449      single         1.0          1.0    234374.0     False
# TR826351       album         1.0         20.0    248330.0      True
# TR529809      single         1.0          1.0    234374.0     False
# TR280904       album         1.0          7.0    302173.0      True
# TR552777       album         1.0          6.0    292000.0      True
#
#           popularity                                        album_image  \
# id
# TR934808        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# TR760029        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# TR916821        39.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# TR480968        47.0  https://i.scdn.co/image/ab67616d0000b27367c03d...
# TR585039        41.0  https://i.scdn.co/image/ab67616d0000b273fcdb60...
# ...              ...                                                ...
# TR434449        57.0  https://i.scdn.co/image/ab67616d0000b2733a7b5b...
# TR826351        24.0  https://i.scdn.co/image/ab67616d0000b273659696...
# TR529809        57.0  https://i.scdn.co/image/ab67616d0000b2733a7b5b...
# TR280904        37.0  https://i.scdn.co/image/ab67616d0000b273659696...
# TR552777        30.0  https://i.scdn.co/image/ab67616d0000b273ab56f8...
#
#            id_album                                             lyrics  \
# id
# TR934808  ALB115557  Oplà, ah\nBdope, chiama due b—\n\nMi candidere...
# TR760029  ALB115557  Greg Willen, non dormire\n(Brr-poh)\n\nT-T-Tro...
# TR916821  ALB115557  Mothz\nYeah, yeah, yeah-yeah\nBdope, chiama du...
# TR480968  ALB730959  Designer sui vestiti penso di essere un outlet...
# TR585039  ALB436151  Bdope (Yeah)\n\nVuole solo me, non fare la gel...
# ...             ...                                                ...
# TR434449  ALB248347  Qui non va, ma questo badabum cha cha\nTira fo...
# TR826351  ALB100713  Odio questa città (città)\nSappiamo che la ver...
# TR529809  ALB248347  Qui non va, ma questo badabum cha cha\nTira fo...
# TR280904  ALB100713  É crudo il suono e questa vibra che ti do\nCru...
# TR552777  ALB412275  Roccia\nMarracash (Marracash!)\nDedicato per m...
#
#           modified_popularity
# id
# TR934808                False
# TR760029                False
# TR916821                False
# TR480968                False
# TR585039                False
# ...                       ...
# TR434449                False
# TR826351                False
# TR529809                False
# TR280904                False
# TR552777                False
#
# [11166 rows x 44 columns]
